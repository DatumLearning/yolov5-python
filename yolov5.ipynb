# %% [markdown]
# <a href="https://colab.research.google.com/github/DatumLearning/yolov5-python/blob/main/yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U ultralytics -q   # ~ >1mins

# %%
import torch , cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-8-9 Python-3.10.12 torch-2.3.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
results = model(cv2.imread("/content/dog.jpg"))

# %%
results
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 576x768 1 bicycle, 1 car, 1 truck, 1 dog
# Speed: 22.2ms pre-process, 441.3ms inference, 7.1ms NMS per image at shape (1, 3, 480, 640)

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=768x576>

# %%
dir(results)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_run',
#  'crop',
#  'files',
#  'ims',
#  'n',
#  'names',
#  'pandas',
#  'pred',
#  'print',
#  'render',
#  's',
#  'save',
#  'show',
#  't',
#  'times',
#  'tolist',
#  'xywh',
#  'xywhn',
#  'xyxy',
#  'xyxyn']

# %%
results.pandas().xyxy[0]
# Out:
#          xmin        ymin        xmax        ymax  confidence  class     name
# 0  132.452026  212.955032  309.932922  542.829651    0.879864     16      dog
# 1  472.382599   77.635513  686.895203  172.401413    0.632460      2      car
# 2  468.864075   79.714088  688.976074  171.705826    0.539469      7    truck
# 3  146.695465  117.461998  567.536865  430.521545    0.431546      1  bicycle
